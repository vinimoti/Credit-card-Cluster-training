# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('CC GENERAL.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# # Data exploration and treatment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# ## Treating the missing data

# %% [markdown]
# ### MINIMUM_PAYMENTS

# %%
plt.hist(df['MINIMUM_PAYMENTS'], density=True, bins=80)
plt.show()

# %%
df['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
nan_min_pay = df[df['MINIMUM_PAYMENTS'].isna()]
nan_min_pay
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 45    C10047  2242.311686           1.000000     437.00             97.00
# 47    C10049  3910.111237           1.000000       0.00              0.00
# 54    C10056     6.660517           0.636364     310.00              0.00
# 55    C10057  1311.995984           1.000000    1283.90           1283.90
# ...      ...          ...                ...        ...               ...
# 8919  C19160    14.524779           0.333333     152.00            152.00
# 8929  C19170   371.527312           0.333333       0.00              0.00
# 8935  C19176   183.817004           1.000000     465.90              0.00
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8946  C19187    19.183215           1.000000     300.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
nan_min_pay.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count   313.000000         313.000000   313.000000        313.000000
# mean    555.441321           0.389403   393.087284        250.433387
# std    1292.687887           0.408341   757.905701        624.453991
# min       0.000000           0.000000     0.000000          0.000000
# 25%       0.187069           0.090909     1.400000          0.000000
# 50%      16.848358           0.181818   130.400000          0.000000
# 75%     286.686616           1.000000   399.950000        176.030000
# max    9164.724752           1.000000  7597.090000       6761.290000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count              313.000000    313.000000           313.000000
# mean               142.653898    559.136698             0.336043
# std                311.289043   1185.132567             0.372517
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# We can clearly see some differences between the data of the original dataframe and the ones which contains most of the nan values...

# %%
nan_min_pay.drop(['CUST_ID'], axis = 1).corr()['MINIMUM_PAYMENTS']
# Out:
# BALANCE                            NaN
# BALANCE_FREQUENCY                  NaN
# PURCHASES                          NaN
# ONEOFF_PURCHASES                   NaN
# INSTALLMENTS_PURCHASES             NaN
# CASH_ADVANCE                       NaN
# PURCHASES_FREQUENCY                NaN
# ONEOFF_PURCHASES_FREQUENCY         NaN
# PURCHASES_INSTALLMENTS_FREQUENCY   NaN
# CASH_ADVANCE_FREQUENCY             NaN
# CASH_ADVANCE_TRX                   NaN
# PURCHASES_TRX                      NaN
# CREDIT_LIMIT                       NaN
# PAYMENTS                           NaN
# MINIMUM_PAYMENTS                   NaN
# PRC_FULL_PAYMENT                   NaN
# TENURE                             NaN
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
corr = df[~df.isin(nan_min_pay)].drop('CUST_ID', axis =1).corr()
corr['MINIMUM_PAYMENTS']
# Out:
# BALANCE                             0.398684
# BALANCE_FREQUENCY                   0.132569
# PURCHASES                           0.093860
# ONEOFF_PURCHASES                    0.048755
# INSTALLMENTS_PURCHASES              0.132172
# CASH_ADVANCE                        0.140107
# PURCHASES_FREQUENCY                 0.003030
# ONEOFF_PURCHASES_FREQUENCY         -0.030327
# PURCHASES_INSTALLMENTS_FREQUENCY    0.030073
# CASH_ADVANCE_FREQUENCY              0.098838
# CASH_ADVANCE_TRX                    0.109739
# PURCHASES_TRX                       0.096333
# CREDIT_LIMIT                        0.126671
# PAYMENTS                            0.126651
# MINIMUM_PAYMENTS                    1.000000
# PRC_FULL_PAYMENT                   -0.140379
# TENURE                              0.059444
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
plt.hist(nan_min_pay['BALANCE'], density=True, bins=80)
plt.show()

# %% [markdown]
# Usually I tend to fill these na values with the median, because it fits better than the mean/average due the high variability in the data (theres a lot of 0's and some few very high, making the average high).

# %% [markdown]
# Note: Linear Regression is not ideal nor the right approach in this situation. The data from 'BALANCE'(X) doesn't follow a Normal Distribution nor have a good correlation to y.

# %%
from sklearn.linear_model import LinearRegression

X = np.array(df[~df.isin(nan_min_pay)]['BALANCE'].dropna()).reshape(-1,1)
y = np.array(df[~df.isin(nan_min_pay)]['MINIMUM_PAYMENTS'].dropna())

reg = LinearRegression()
reg.fit(X,y)
#reg.score(X,y)
#reg.coef_
#reg.intercept_
#reg.predict(nan_min_pay['MINIMUM_PAYMENTS'])
# Out:
# LinearRegression()

# %% [markdown]
# I chose the balace because it has the most correlation to minimun_payments (even if it's low) and i want to just do a simple regression to see where it takes

# %%
print(f'''score: {reg.score(X,y)}
slope/coefficient: {reg.coef_}
intercept: {reg.intercept_}''')
# Out:
# score: 0.15894902667581567
# slope/coefficient: [0.45137109]
# intercept: 141.54262993378268

# %% [markdown]
# The score (R²) is very low, but i think it could suit the data and I also used it to train (my own ability) some uses in Scikit-Learn

# %%
print(df['MINIMUM_PAYMENTS'].median(),'---', df['MINIMUM_PAYMENTS'].mean())
# Out:
# 312.343947 --- 864.2065423050828

# %%
pred = reg.predict(np.array(nan_min_pay['BALANCE']).reshape(-1,1))
pred.mean()
# Out:
# 392.2527865209126

# %%
pred = pd.Series(pred)
pred.describe()
# Out:
# count     313.000000
# mean      392.252787
# std       583.481945
# min       141.542630
# 25%       141.627067
# 50%       149.147492
# 75%       270.944681
# max      4278.234464
# dtype: float64

# %%
for i in range(len(pred)): 
    treated = nan_min_pay.replace(nan_min_pay['MINIMUM_PAYMENTS'].iloc[i], pred[i])

# %%
treated
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 45    C10047  2242.311686           1.000000     437.00             97.00
# 47    C10049  3910.111237           1.000000       0.00              0.00
# 54    C10056     6.660517           0.636364     310.00              0.00
# 55    C10057  1311.995984           1.000000    1283.90           1283.90
# ...      ...          ...                ...        ...               ...
# 8919  C19160    14.524779           0.333333     152.00            152.00
# 8929  C19170   371.527312           0.333333       0.00              0.00
# 8935  C19176   183.817004           1.000000     465.90              0.00
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8946  C19187    19.183215           1.000000     300.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# ### The only one in CREDIT

# %%
df[df['CREDIT_LIMIT'].isna()]
# Out:
#      CUST_ID    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5203  C15349  18.400472           0.166667        0.0               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5203                     0.0    186.853063                  0.0
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5203                         0.0                               0.0
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5203                0.166667                 1              0           NaN
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5203  9.040017         14.418723               0.0       6

# %%
df['CREDIT_LIMIT'].describe()
# Out:
# count     8949.000000
# mean      4494.449450
# std       3638.815725
# min         50.000000
# 25%       1600.000000
# 50%       3000.000000
# 75%       6500.000000
# max      30000.000000
# Name: CREDIT_LIMIT, dtype: float64

# %%
plt.hist(df['CREDIT_LIMIT'], density=True, bins=80)
plt.show()

# %%
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median(), inplace=True)

# %% [markdown]
# Because it's only one value let's just use the median

# %%
df_new = pd.concat([df.dropna(),treated])
#now we can drop all the nan values

# %%
df_new.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
#replaced the missing data with a estimate value by a simple linear regression (which has a acc of 15% :/)

# %% [markdown]
# ## Which column is essential for a clustering model?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df_new.drop(columns = ['CUST_ID'], inplace = True, axis=1)

# %% [markdown]
# The only non numerical column is the ID. It is not categorical, just an ID.

# %%
df_new['TENURE'].value_counts(normalize = True)
# Out:
# TENURE
# 12    0.847374
# 11    0.040782
# 10    0.026369
# 6     0.022793
# 8     0.021899
# 7     0.021229
# 9     0.019553
# Name: proportion, dtype: float64

# %% [markdown]
# Ternure is another arbritary and indicates just a cycle of a contract. Let's drop for now

# %%
df_new.drop(columns = ['TENURE'], inplace = True, axis=1)

# %% [markdown]
# # Clustering data

# %% [markdown]
# First let's normalize. I am dealing with multiples measure units (monetary, times, binary) and is needed equalize the 'weight' of each data

# %%
from sklearn.preprocessing import Normalizer

values = Normalizer().fit_transform(df_new.values)
values
# Out:
# array([[3.93555441e-02, 7.87271593e-04, 9.17958473e-02, ...,
#         1.94178127e-01, 1.34239194e-01, 0.00000000e+00],
#        [2.93875903e-01, 8.34231560e-05, 0.00000000e+00, ...,
#         3.76516684e-01, 9.84037959e-02, 2.03923046e-05],
#        [3.10798149e-01, 1.24560965e-04, 9.63068011e-02, ...,
#         7.74852335e-02, 7.81351982e-02, 0.00000000e+00],
#        ...,
#        [1.11037510e-01, 6.04065497e-04, 2.81434115e-01, ...,
#         0.00000000e+00, 9.07314704e-02, 0.00000000e+00],
#        [4.54849108e-02, 1.95814124e-04, 2.37968300e-01, ...,
#         0.00000000e+00, 3.52938758e-02, 0.00000000e+00],
#        [1.69619123e-02, 8.84205920e-04, 2.65261776e-01, ...,
#         2.43918214e-01, 1.32808948e-01, 0.00000000e+00]])

# %%
from sklearn.cluster import KMeans

kmeans = KMeans (n_clusters = 5, n_init = 10, max_iter = 300)
y_pred = kmeans.fit_predict(values)

y_pred
# Out:
# array([1, 3, 1, ..., 1, 1, 1])

# %%
len(y_pred)
# Out:
# 8950

# %% [markdown]
# ## Validation

# %%
#Coeficiente de Sillhouette
#Distância Euclidiana
#alfa distância média entre o ponto e outros pontos dentro do mesmo cluster
#beta distância entre o ponto e os pontos de outros clusters (menor média para o outro cluster)

#Se maior que 0 == ok

# %%
from sklearn import metrics

labels = kmeans.labels_

silhouette = metrics.silhouette_score(values, labels, metric = 'euclidean')
print(silhouette)
# Out:
# 0.365563452125199

# %%
#Índice Davies-Bouldin
#Similaridade entre dois clusters
#Distância Euclidiana entre os centroides de cada Cluster
#Quanto maior o valor pior (clusters mais próximos) o desempenho do modelo

# %%
dbs = metrics.davies_bouldin_score(values, labels)
print (dbs)
# Out:
# 1.0752292595886928

# %%
#Calinski
#cov entre clusters (somatória) dispersão da covariância dentro do cluster dividid
#multiplicado pela quantidade de clusters
#quanto maior o valor mais disperso os clusters estão entre a dispersão interna

# %%
calinski = metrics.calinski_harabasz_score(values, labels)
print (calinski)
# Out:
# 3445.6840241672

# %%
#function to continually use kmeans for validation
def clustering_algorithm(n_clusters, dataset):
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, max_iter=300)
    labels = kmeans.fit_predict(dataset)
    s = metrics.silhouette_score(dataset, labels, metric='euclidean')
    dbs = metrics.davies_bouldin_score(dataset, labels)
    calinski = metrics.calinski_harabasz_score(dataset, labels)
    return s, dbs, calinski

# %%
#3 clusters
s1, dbs1, calinski1 = clustering_algorithm(3, values)
print(s1, dbs1, calinski1)
# Out:
# 0.3282332408019958 1.3082880400472492 3538.5176769579903

# %%
#5 clusters
s2, dbs2, calinski2 = clustering_algorithm(5, values)
print(s2, dbs2, calinski2)
# Out:
# 0.3655739471771576 1.0753639323600743 3445.671273298471

# %%
for n in range(2,20):
    print(clustering_algorithm(n, values),'-', n)
# Out:
# (0.30008947147400633, 1.5147580529463909, 3334.345520996809) - 2
# (0.3282332408019958, 1.3082880400472492, 3538.5176769579903) - 3
# (0.3492402350772311, 1.2204235253124611, 3541.7125624135024) - 4
# (0.3654747690120409, 1.0752859995256423, 3445.673017618754) - 5
# (0.3661128324272595, 1.044539667002377, 3539.268419026567) - 6
# (0.3289294338859848, 1.1506374468541882, 3414.8582290984245) - 7
# (0.31046350607137957, 1.171570133396377, 3255.336350301602) - 8
# (0.31053858862660233, 1.1913147831675674, 3123.229956888222) - 9
# (0.35290385118856576, 1.1139974743967, 3036.382739180022) - 10
# (0.30572088312780077, 1.1435922045699172, 2974.2912751821777) - 11
# (0.30658578736335107, 1.1108573538228395, 2940.112130749591) - 12
# (0.2963945486878627, 1.1450398064882967, 2856.9353326526125) - 13
# (0.30146620411848685, 1.1502192944326242, 2782.8405825829236) - 14
# (0.3034809606215617, 1.1553975720285736, 2723.6963811889696) - 15
# ...

# %% [markdown]
# Let's test how the model with 5 clusters perform in comparisson to a random dataset

# %%
df_new.shape
# Out:
# (8950, 16)

# %%
random_data = np.random.rand(8950, 16)
rand_sim = clustering_algorithm(5, random_data)

# %%
print(rand_sim)
print(s2,dbs2,calinski2)
# Out:
# (0.039410324444809006, 3.506085835109695, 301.5778575290102)
# 0.3655739471771576 1.0753639323600743 3445.671273298471

# %% [markdown]
# The performance showed that the clustering is working well.
# So let's test how solid (or stable) the model is througout the dataset (df_new) splitting the dataset in 3 parts

# %%
set1, set2, set3 = np.array_split(values, 3)
split1 = clustering_algorithm(5, set1)
split2 = clustering_algorithm(5, set2)
split3 = clustering_algorithm(5, set3)

# %%
print(split1)
print(split2)
print(split3)
print(s2,dbs2,calinski2)
# Out:
# (0.3717983676738176, 1.037579912970756, 1217.8991573753297)
# (0.3465728268545157, 1.145148968676848, 1182.9679971123899)
# (0.37008335990138136, 1.1589400386403124, 1168.9810545049077)
# 0.3655739471771576 1.0753639323600743 3445.671273298471

# %% [markdown]
# A good performance!\
# Silhouette > 0 \
# Davies-Bouldin stable and not too high (compared to the random one)\
# Calinski is high

# %%
print(((split1[0]+split2[0]+split3[0])/3),((split1[1]+split2[1]+split3[1])/3),((split1[2]+split2[2]+split3[2])))
# Out:
# 0.36281818480990485 1.1138896400959721 3569.8482089926274

# %%
plt.scatter(x=df_new['PURCHASES'], y=df_new['PAYMENTS'], c = labels, s=5, cmap='rainbow')
plt.xlabel('Total value of purchases')
plt.ylabel('Total value of payments')
plt.show()

# %%
df_new['cluster'] = labels

# %%
sns.pairplot(data = df_new, y_vars = ['PAYMENTS'], hue = 'cluster')
# Out:
# C:\Users\T-Gamer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_new
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8919    14.524779           0.333333     152.00            152.00
# 8929   371.527312           0.333333       0.00              0.00
# 8935   183.817004           1.000000     465.90              0.00
# 8944   193.571722           0.833333    1012.73           1012.73
# 8946    19.183215           1.000000     300.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
df_new.groupby('cluster').count()
# Out:
#          BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0           2647               2647       2647              2647
# 1           3280               3280       3280              3280
# 2            412                412        412               412
# 3           1074               1074       1074              1074
# 4           1537               1537       1537              1537
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                          2647          2647                 2647
# 1                          3280          3280                 3280
# 2                           412           412                  412
# 3                          1074          1074                 1074
# 4                          1537          1537                 1537
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# ...

# %%
df_new.groupby('cluster').describe().T
# Out:
# cluster                           0            1            2            3  \
# BALANCE          count  2647.000000  3280.000000   412.000000  1074.000000
#                  mean   3039.410289   443.553003  1987.146873  1796.066730
#                  std    2478.931283   846.404850  1852.215743  1981.709522
#                  min       6.824905     0.000000    70.794108     0.000000
#                  25%    1257.895616    23.287145  1020.146724   507.348768
# ...                             ...          ...          ...          ...
# PRC_FULL_PAYMENT min       0.000000     0.000000     0.000000     0.000000
#                  25%       0.000000     0.000000     0.000000     0.000000
#                  50%       0.000000     0.000000     0.000000     0.083333
#                  75%       0.000000     0.444444     0.000000     0.142857
#                  max       0.600000     1.000000     1.000000     1.000000
#
# cluster                           4
# ...

# %%
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[5.04511661e-01 2.71972861e-04 6.16602696e-02 3.61325001e-02
#   2.55494991e-02 2.52748978e-01 6.72912881e-05 2.56785836e-05
#   4.50694616e-05 5.74642874e-05 1.15710936e-03 1.33167538e-03
#   7.19419834e-01 1.66289927e-01 1.77820682e-01 5.52720859e-07]
#  [6.90034834e-02 2.30688189e-04 1.21582050e-01 4.81121170e-02
#   7.35701618e-02 2.45183136e-02 1.72863877e-04 3.37024702e-05
#   1.40305314e-04 7.96049015e-06 1.24685855e-04 2.86327616e-03
#   9.44120453e-01 1.53696752e-01 5.25641255e-02 7.60909806e-05]
#  [3.32972556e-01 2.68240066e-04 1.58923673e-01 3.62178588e-02
#   1.23089552e-01 5.82140753e-02 1.66817881e-04 2.64295391e-05
#   1.47135264e-04 1.92748591e-05 4.26896159e-04 3.86195702e-03
#   3.76646957e-01 2.52402941e-01 6.79571553e-01 4.22964707e-06]
#  [2.35196414e-01 2.16280232e-04 6.07428412e-02 3.46334219e-02
#   2.61146194e-02 3.99942472e-01 5.28056059e-05 2.06140099e-05
#   3.52820958e-05 6.54468530e-05 1.57008110e-03 1.12771594e-03
# ...

# %%
max = centroids[0]
for i in range(len(max)):
    print(df_new.columns.values[i],'\n{:.4f}'.format( centroids[:, i].var()))
# Out:
# BALANCE
# 0.0224
# BALANCE_FREQUENCY
# 0.0000
# PURCHASES
# 0.0197
# ONEOFF_PURCHASES
# 0.0076
# INSTALLMENTS_PURCHASES
# 0.0036
# CASH_ADVANCE
# 0.0225
# PURCHASES_FREQUENCY
# 0.0000
# ONEOFF_PURCHASES_FREQUENCY
# 0.0000
# PURCHASES_INSTALLMENTS_FREQUENCY
# 0.0000
# CASH_ADVANCE_FREQUENCY
# 0.0000
# CASH_ADVANCE_TRX
# 0.0000
# PURCHASES_TRX
# 0.0000
# CREDIT_LIMIT
# 0.0361
# PAYMENTS
# 0.0279
# MINIMUM_PAYMENTS
# 0.0545
# PRC_FULL_PAYMENT
# 0.0000

# %%
variancy = [centroids[:, i].var() for i in range(len(centroids[0]))]
var_df = pd.DataFrame(data = np.round(variancy,4), index = df_new.columns.drop(['cluster']), columns = ['variancy'])

# %%
var_df.sort_values(by=['variancy'], ascending=False)
# Out:
#                                   variancy
# MINIMUM_PAYMENTS                    0.0545
# CREDIT_LIMIT                        0.0361
# PAYMENTS                            0.0279
# CASH_ADVANCE                        0.0225
# BALANCE                             0.0224
# PURCHASES                           0.0197
# ONEOFF_PURCHASES                    0.0076
# INSTALLMENTS_PURCHASES              0.0036
# BALANCE_FREQUENCY                   0.0000
# PURCHASES_FREQUENCY                 0.0000
# ONEOFF_PURCHASES_FREQUENCY          0.0000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.0000
# CASH_ADVANCE_FREQUENCY              0.0000
# CASH_ADVANCE_TRX                    0.0000
# PURCHASES_TRX                       0.0000
# PRC_FULL_PAYMENT                    0.0000

# %%
var_df = var_df.loc[var_df.values>0.01]
var_df
# Out:
#                   variancy
# BALANCE             0.0224
# PURCHASES           0.0197
# CASH_ADVANCE        0.0225
# CREDIT_LIMIT        0.0361
# PAYMENTS            0.0279
# MINIMUM_PAYMENTS    0.0545

# %%
df_new[var_df.T.columns].describe()
# Out:
#             BALANCE     PURCHASES  CASH_ADVANCE  CREDIT_LIMIT      PAYMENTS  \
# count   8950.000000   8950.000000   8950.000000   8950.000000   8950.000000
# mean    1564.474828   1003.204834    978.871112   4494.282473   1733.143852
# std     2081.531879   2136.634782   2097.163877   3638.646702   2895.063757
# min        0.000000      0.000000      0.000000     50.000000      0.000000
# 25%      128.281915     39.635000      0.000000   1600.000000    383.276166
# 50%      873.385231    361.280000      0.000000   3000.000000    856.901546
# 75%     2054.140036   1110.130000   1113.821139   6500.000000   1901.134317
# max    19043.138560  49039.570000  47137.211760  30000.000000  50721.483360
#
#        MINIMUM_PAYMENTS
# count       8950.000000
# mean         839.236306
# std         2334.276721
# min            0.019163
# 25%          163.028164
# 50%          289.628402
# 75%          788.713501
# max        76406.207520

# %%
description_mean = df_new.groupby('cluster')[var_df.T.columns] 
n_clients = description_mean.size()
description_mean = description_mean.mean().round(2)
description_mean['n_clients'] = n_clients
description_mean
# Out:
#          BALANCE  PURCHASES  CASH_ADVANCE  CREDIT_LIMIT  PAYMENTS  \
# cluster
# 0        3039.41     385.15       1636.11       4497.62    969.11
# 1         443.55     629.31        141.99       5130.79    814.04
# 2        1987.15     858.33        420.11       2226.70   1338.97
# 3        1796.07     477.10       3267.66       3981.54   4710.62
# 4        1141.31    3271.97        183.38       4096.33   3035.45
#
#          MINIMUM_PAYMENTS  n_clients
# cluster
# 0                 1018.25       2647
# 1                  217.29       3280
# 2                 6032.35        412
# 3                  734.07       1074
# 4                  539.63       1537

# %%
description_mean.sort_values(by ='BALANCE')
# Out:
#          BALANCE  PURCHASES  CASH_ADVANCE  CREDIT_LIMIT  PAYMENTS  \
# cluster
# 1         443.55     629.31        141.99       5130.79    814.04
# 4        1141.31    3271.97        183.38       4096.33   3035.45
# 3        1796.07     477.10       3267.66       3981.54   4710.62
# 2        1987.15     858.33        420.11       2226.70   1338.97
# 0        3039.41     385.15       1636.11       4497.62    969.11
#
#          MINIMUM_PAYMENTS  n_clients
# cluster
# 1                  217.29       3280
# 4                  539.63       1537
# 3                  734.07       1074
# 2                 6032.35        412
# 0                 1018.25       2647
